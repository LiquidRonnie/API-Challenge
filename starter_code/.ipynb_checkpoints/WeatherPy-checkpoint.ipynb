# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %%
cities
# Out:
# ['kodiak',
#  'nantucket',
#  'barrow',
#  'santa cruz',
#  'nizwa',
#  'kikinda',
#  'jamestown',
#  'dawlatabad',
#  'northam',
#  'rikitea',
#  'beringovskiy',
#  'jinchengjiang',
#  'ushuaia',
#  'saryg-sep',
#  'praia da vitoria',
#  'leshukonskoye',
#  'napasar',
#  'tuktoyaktuk',
#  'avarua',
#  'pakxan',
#  'linqiong',
#  'neuquen',
#  'tasiilaq',
#  'castro',
#  'nuuk',
#  'chokurdakh',
#  'punta arenas',
#  'hermanus',
#  'hobart',
#  'sabzevar',
#  'mar del plata',
#  'cherskiy',
#  'saint-philippe',
#  'abha',
#  'bredasdorp',
#  'sale',
#  'saldanha',
#  'honiara',
#  'lagoa',
#  'albany',
#  'umm lajj',
#  'puerto cabezas',
#  'raga',
#  'nortelandia',
#  'urucara',
#  'severo-kurilsk',
#  'butaritari',
#  'temaraia',
#  'haines junction',
#  'ust-kuyga',
#  'busselton',
#  'rorvik',
#  'beyneu',
#  'mataura',
#  'bluff',
#  'orlik',
#  'srednekolymsk',
#  'illoqqortoormiut',
#  'koindu',
#  'lompoc',
#  'karratha',
#  'mount gambier',
#  'mys shmidta',
#  'taolanaro',
# ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
query_url

# set up lists to hold reponse info
lat = []
lng= []
temp = []
humidity = []
cloud = []
wind_speed = []
country = []
date = []
clean_city_list= []

# assign variables to count record number and set number
record_num = 0
set_num = 1

print('''
Beginning Data Retrieval
-------------------------------''')

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        if record_num == 50:
            set_num +=1
            record_num = 1
            clean_city_list.append(city)
        else:
            record_num +=1
            clean_city_list.append(city)
        print(f"Processing Record {record_num} of Set {set_num} | {city}")
    except (KeyError, IndexError):
        print("City not found....Skipping............")
print('''-------------------------------
Data Retrieval Complete
-------------------------------
''')
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | nantucket
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | santa cruz
# Processing Record 5 of Set 1 | nizwa
# Processing Record 6 of Set 1 | kikinda
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | dawlatabad
# Processing Record 9 of Set 1 | northam
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | beringovskiy
# City not found....Skipping............
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | saryg-sep
# Processing Record 14 of Set 1 | praia da vitoria
# Processing Record 15 of Set 1 | leshukonskoye
# Processing Record 16 of Set 1 | napasar
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | pakxan
# Processing Record 20 of Set 1 | linqiong
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create DataFrame
weather_df = pd.DataFrame({"City":clean_city_list,
                          "Lat":lat, 
                          "Lng":lng,
                          "Max_temp":temp,
                          "Humidity":humidity,
                          "Cloudiness":cloud,
                          "Wind_speed":wind_speed,
                          "Country":country,
                          "Date":date})
weather_df = weather_df.set_index("City").sort_index()
weather_df
# Out:
#                        Lat       Lng  Max_temp  Humidity  Cloudiness  \
# City
# aasiaat            68.7098  -52.8699     27.55        82         100
# abatskoye          56.2875   70.4555     79.38        35          18
# abha               18.2164   42.5053     73.40        43          20
# abu dhabi          24.4667   54.3667     89.60        62           0
# aburi               5.8472   -0.1775     80.60        89           0
# ...                    ...       ...       ...       ...         ...
# zhanaozen          43.3000   52.8000     79.93        22           1
# zheleznodorozhnyy  55.7503   38.0042     66.20        88           0
# zhigansk           66.7697  123.3711     52.45        44         100
# zhongxing          33.7039  118.6792     71.35        97         100
# zuwarah            32.9312   12.0820     66.78        78           0
#
#                    Wind_speed Country        Date
# City
# aasiaat                  3.02      GL  1621056323
# ...

# %%
# convert to .csv file
weather_df.to_csv("../output_data/weather_data_file.csv")

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max_temp    Humidity  Cloudiness  Wind_speed  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean    19.536635   12.031968   64.779212   68.267951   50.334501    8.000665
# std     33.157016   88.253964   17.186300   22.713934   37.899940    5.573132
# min    -54.800000 -175.200000   19.900000    1.000000    0.000000    0.200000
# 25%     -8.160700  -65.941350   52.000000   56.000000   11.500000    3.980000
# 50%     22.566700   16.333300   65.500000   71.000000   50.000000    6.710000
# 75%     48.022400   80.906000   78.800000   87.000000   90.000000   11.180000
# max     78.218600  179.316700   99.000000  100.000000  100.000000   36.930000
#
#                Date
# count  5.710000e+02
# mean   1.621056e+09
# std    8.838262e+01
# min    1.621056e+09
# 25%    1.621056e+09
# 50%    1.621056e+09
# 75%    1.621056e+09
# max    1.621056e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# find max value of Humidity
weather_df.head()
weather_df["Humidity"].max()
# Out:
# 100

# %% [markdown]
# Will not drop max value, as max Humidity value is equal to 100%

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max_temp    Humidity  Cloudiness  Wind_speed  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean    19.536635   12.031968   64.779212   68.267951   50.334501    8.000665
# std     33.157016   88.253964   17.186300   22.713934   37.899940    5.573132
# min    -54.800000 -175.200000   19.900000    1.000000    0.000000    0.200000
# 25%     -8.160700  -65.941350   52.000000   56.000000   11.500000    3.980000
# 50%     22.566700   16.333300   65.500000   71.000000   50.000000    6.710000
# 75%     48.022400   80.906000   78.800000   87.000000   90.000000   11.180000
# max     78.218600  179.316700   99.000000  100.000000  100.000000   36.930000
#
#                Date
# count  5.710000e+02
# mean   1.621056e+09
# std    8.838262e+01
# min    1.621056e+09
# 25%    1.621056e+09
# 50%    1.621056e+09
# 75%    1.621056e+09
# max    1.621056e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# create scatter plot
fig, ax= plt.subplots()
ax.scatter(weather_df["Lat"], weather_df["Max_temp"], marker="o", color="green");
ax.set(ylabel="Max Temperature (F)",
       xlabel="Latitude",
       title="City Latitude vs. Max Temperaute (5/14/21)");
fig.tight_layout();
ax.grid();
plt.savefig("../output_data/lat_v_temp.png")

# %% [markdown]
# Observation 1: We can see, and as expected, the temperatures gets warmer the closer it gets to the equator. this graph also shows the temperaure dractically decreaes as it gets closer to the North Pole; however, it shoes a temperaure of about 20. Perhaps it should be colder.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# create scatter plot
fig2, a2x= plt.subplots()
a2x.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o", color="red");
a2x.set(ylabel="Humidity Percent",
       xlabel="Latitude",
       title="City Latitude vs. Humidity (5/14/21)");
fig2.tight_layout();
a2x.grid();
plt.savefig("../output_data/lat_v_humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# create scatter plot
fig3, ax3= plt.subplots()
ax3.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o", color="c");
ax3.set(ylabel="Cloudiness Percent",
       xlabel="Latitude",
       title="City Latitude vs. Cloudiness (5/14/21)");
fig3.tight_layout();
ax3.grid();
plt.savefig("../output_data/lat_v_Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# create scatter plot
fig4, ax4= plt.subplots()
ax4.scatter(weather_df["Lat"], weather_df["Wind_speed"], marker="o", color="purple");
ax4.set(ylabel="Wind_speed (mph)",
       xlabel="Latitude",
       title="City Latitude vs. Wind_speed (5/14/21)");
fig4.tight_layout();
ax4.grid();
plt.savefig("../output_data/lat_v_Windspeed.png")

# %% [markdown]
# ## Linear Regression

# %%
# Identify Northern Hemisphere for each city
northern_df = pd.DataFrame(weather_df.loc[weather_df["Lat"] >= 0])
northern_df
# Out:
#                        Lat       Lng  Max_temp  Humidity  Cloudiness  \
# City
# aasiaat            68.7098  -52.8699     27.55        82         100
# abatskoye          56.2875   70.4555     79.38        35          18
# abha               18.2164   42.5053     73.40        43          20
# abu dhabi          24.4667   54.3667     89.60        62           0
# aburi               5.8472   -0.1775     80.60        89           0
# ...                    ...       ...       ...       ...         ...
# zhanaozen          43.3000   52.8000     79.93        22           1
# zheleznodorozhnyy  55.7503   38.0042     66.20        88           0
# zhigansk           66.7697  123.3711     52.45        44         100
# zhongxing          33.7039  118.6792     71.35        97         100
# zuwarah            32.9312   12.0820     66.78        78           0
#
#                    Wind_speed Country        Date
# City
# aasiaat                  3.02      GL  1621056323
# ...

# %%
# Identify Southern Hemisphere for each city
southern_df = pd.DataFrame(weather_df.loc[weather_df["Lat"] < 0])
southern_df
# Out:
#                    Lat       Lng  Max_temp  Humidity  Cloudiness  Wind_speed  \
# City
# ahipara       -35.1667  173.1667     63.28        82           4        6.29
# airai          -8.9266  125.4092     71.73        50         100        4.94
# aitape         -3.1374  142.3475     87.03        69          47        9.26
# alice springs -23.7000  133.8833     66.20        34           0       12.66
# almeirim       -1.5233  -52.5817     73.94        97         100        2.53
# ...                ...       ...       ...       ...         ...         ...
# valparaiso    -33.0393  -71.6273     55.00        80         100        8.10
# vao           -22.6667  167.4833     75.88        82          20       13.42
# waipawa       -41.4122  175.5153     60.80        77           0       11.50
# walvis bay    -22.9575   14.5053     57.20        38           0        4.61
# yeppoon       -23.1333  150.7333     78.80        21           0        8.05
#
#               Country        Date
# ...

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Obtain slope, intercept, rvalue, pvalue, standard_error for linear regression 
slope, intercept, rvalue, pvalue, standard_error = linregress(northern_df["Lat"], northern_df["Max_temp"])
print(f"the r-value is {rvalue**2}")
line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"
regress_values = northern_df["Lat"] * slope + intercept

# create scatter plot
fig5, ax5= plt.subplots()
ax5.scatter(northern_df["Lat"], northern_df["Max_temp"], marker="o", color="green");
ax5.plot(northern_df["Lat"],regress_values,"r-");
ax5.set(ylabel="Max Temperature (F)",
       xlabel="Latitude",
       title="Northern Heemisphere: City Latitude vs. Max Temperaute (5/14/21)");
ax5.annotate(line_eq, (0,30),fontsize=15,color="red");
fig5.tight_layout();
ax5.grid();
plt.savefig("../output_data/north_lat_v_temp.png")
# Out:
# the r-value is 0.6600832991616468

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Obtain slope, intercept, rvalue, pvalue, standard_error for linear regression 
slope, intercept, rvalue, pvalue, standard_error = linregress(southern_df["Lat"], southern_df["Max_temp"])
print(f"the r-value is {rvalue**2}")
line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"
regress_values = southern_df["Lat"] * slope + intercept

# create scatter plot
fig6, ax6= plt.subplots()
ax6.scatter(southern_df["Lat"], southern_df["Max_temp"], marker="o", color="green");
ax6.plot(southern_df["Lat"],regress_values,"r-");
ax6.set(ylabel="Max Temperature (F)",
       xlabel="Latitude",
       title="Southern Heemisphere: City Latitude vs. Max Temperaute (5/14/21)");
ax6.annotate(line_eq, (-50,70),fontsize=15,color="red");
fig6.tight_layout();
ax6.grid();
plt.savefig("../output_data/south_lat_v_temp.png")
# Out:
# the r-value is 0.49634800546214686

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Obtain slope, intercept, rvalue, pvalue, standard_error for linear regression 
slope, intercept, rvalue, pvalue, standard_error = linregress(northern_df["Lat"], northern_df["Humidity"])
print(f"the r-value is {rvalue**2}")
line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"
regress_values = northern_df["Lat"] * slope + intercept

# create scatter plot
fig7, ax7= plt.subplots()
ax7.scatter(northern_df["Lat"], northern_df["Humidity"], marker="o", color="red");
ax7.plot(northern_df["Lat"],regress_values,"b-");
ax7.set(ylabel="Humidity",
       xlabel="Latitude",
       title="Northern Heemisphere: City Latitude vs. Humidity (5/14/21)");
ax7.annotate(line_eq, (50,0),fontsize=15,color="blue");
fig7.tight_layout();
ax7.grid();
plt.savefig("../output_data/north_lat_v_Humidity.png")
# Out:
# the r-value is 0.0020364504142843906

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Obtain slope, intercept, rvalue, pvalue, standard_error for linear regression 
slope, intercept, rvalue, pvalue, standard_error = linregress(southern_df["Lat"], southern_df["Humidity"])
print(f"the r-value is {rvalue**2}")
line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"
regress_values = southern_df["Lat"] * slope + intercept

# create scatter plot
fig8, ax8= plt.subplots()
ax8.scatter(southern_df["Lat"], southern_df["Humidity"], marker="o", color="red");
ax8.plot(southern_df["Lat"],regress_values,"b-");
ax8.set(ylabel="Humidity",
       xlabel="Latitude",
       title="Southern Heemisphere: City Latitude vs. Humidity (5/14/21)");
ax8.annotate(line_eq, (-20,40),fontsize=15,color="blue");
fig8.tight_layout();
ax8.grid();
plt.savefig("../output_data/south_lat_v_Humidity.png")
# Out:
# the r-value is 0.024000338645560722

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Obtain slope, intercept, rvalue, pvalue, standard_error for linear regression 
slope, intercept, rvalue, pvalue, standard_error = linregress(northern_df["Lat"], northern_df["Cloudiness"])
print(f"the r-value is {rvalue**2}")
line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"
regress_values = northern_df["Lat"] * slope + intercept

# create scatter plot
fig9, ax9= plt.subplots()
ax9.scatter(northern_df["Lat"], northern_df["Cloudiness"], marker="o", color="c");
ax9.plot(northern_df["Lat"],regress_values,"r-");
ax9.set(ylabel="Cloudiness Percent",
       xlabel="Latitude",
       title="Northern Heemisphere: City Latitude vs. Cloudiness (5/14/21)");
ax9.annotate(line_eq, (50,30),fontsize=15,color="red");
fig9.tight_layout();
ax9.grid();
plt.savefig("../output_data/north_lat_v_Cloudiness.png")
# Out:
# the r-value is 0.034023991474837804

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Obtain slope, intercept, rvalue, pvalue, standard_error for linear regression 
slope, intercept, rvalue, pvalue, standard_error = linregress(southern_df["Lat"], southern_df["Cloudiness"])
print(f"the r-value is {rvalue**2}")
line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"
regress_values = southern_df["Lat"] * slope + intercept

# create scatter plot
fig10, ax10= plt.subplots()
ax10.scatter(southern_df["Lat"], southern_df["Cloudiness"], marker="o", color="c");
ax10.plot(southern_df["Lat"],regress_values,"r-");
ax10.set(ylabel="Cloudiness Percent",
       xlabel="Latitude",
       title="Southern Heemisphere: City Latitude vs. Cloudiness (5/14/21)");
ax10.annotate(line_eq, (-50,20),fontsize=15,color="red");
fig10.tight_layout();
ax10.grid();
plt.savefig("../output_data/south_lat_v_Cloudiness.png")
# Out:
# the r-value is 0.023958804977617307

# %% [markdown]
# Observation 2: There seems to be no corrolation between cloudiness and latitude in the northern and southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Obtain slope, intercept, rvalue, pvalue, standard_error for linear regression 
slope, intercept, rvalue, pvalue, standard_error = linregress(northern_df["Lat"], northern_df["Wind_speed"])
print(f"the r-value is {rvalue**2}")
line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"
regress_values = northern_df["Lat"] * slope + intercept

# create scatter plot
fig11, ax11= plt.subplots()
ax11.scatter(northern_df["Lat"], northern_df["Wind_speed"], marker="o", color="purple");
ax11.plot(northern_df["Lat"],regress_values,"r-");
ax11.set(ylabel="Wind_speed (mph)",
       xlabel="Latitude",
       title="Northern Heemisphere: City Latitude vs. Wind_speed (5/14/21)");
ax11.annotate(line_eq, (10,15),fontsize=15,color="red");
fig11.tight_layout();
ax11.grid();
plt.savefig("../output_data/north_lat_v_Windspeed.png")
# Out:
# the r-value is 0.003692545395417078

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Obtain slope, intercept, rvalue, pvalue, standard_error for linear regression 
slope, intercept, rvalue, pvalue, standard_error = linregress(southern_df["Lat"], southern_df["Wind_speed"])
print(f"the r-value is {rvalue**2}")
line_eq = f"y= {round(slope,2)}x + {round(intercept,2)}"
regress_values = southern_df["Lat"] * slope + intercept


# create scatter plot
fig12, ax12= plt.subplots()
ax12.scatter(southern_df["Lat"], southern_df["Wind_speed"], marker="o", color="purple");
ax12.plot(southern_df["Lat"],regress_values,"r-");
ax12.set(ylabel="Wind_speed (mph)",
       xlabel="Latitude",
       title="Southern Heemisphere: City Latitude vs. Wind_speed (5/14/21)");
ax12.annotate(line_eq, (-48,8),fontsize=15,color="red");
fig12.tight_layout();
ax12.grid();
plt.savefig("../output_data/south_lat_v_Windspeed.png")
# Out:
# the r-value is 0.007411712003180874

# %% [markdown]
# Observation 3: There seemms to be a stronger corrolation between latitude and wind speed in the norther hemiosphere than on the southern hemisphere. they seem to be reacheing a wind speed of about 0 - 10 mph. whereras, the southern hemisephere seems to have more wind closer to the equator.
